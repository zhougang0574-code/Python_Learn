# %% [markdown]
# # 模块 & 包管理 · 练习

# %% [markdown]
# ### 1、创建并导入自定义模块

# %%
# 用 %%writefile 创建一个 string_utils.py 文件，里面定义两个函数：
# - reverse_str(s)：返回反转后的字符串
# - count_vowels(s)：返回字符串里元音字母（aeiouAEIOU）的个数
# 写完后在下一个 cell import 这个模块，测试：
# reverse_str("hello") -> "olleh"
# count_vowels("hello world") -> 3

# 在这里写你的代码（这个 cell 用 %%writefile，下一个 cell 写测试代码）

# %%
# 这里写测试代码：import string_utils，调用上面两个函数并打印结果

# %% [markdown]
# ### 2、`__name__ == "__main__"` 验证

# %%
# 用 %%writefile 创建一个 calc.py：
# - 定义函数 square(x)，返回 x 的平方
# - 用 if __name__ == "__main__": 包裹一段代码，调用 square(5) 并打印结果
# 写完后：
# 1. 先 import calc，观察有没有触发 if __name__ == "__main__" 里的代码
# 2. 再用 !python calc.py 直接运行这个文件，观察这次有没有触发
# 期望现象：import 时不触发，!python calc.py 直接运行时会触发

# 在这里写你的代码

# %% [markdown]
# ### 3、创建一个简单的包

# %%
# 创建一个包 shapes/，包含：
# - shapes/__init__.py（空文件即可，或者随便打印一句话）
# - shapes/circle.py，里面定义函数 area(r)，返回 3.14 * r * r
# 创建好之后，用 from shapes.circle import area 导入并计算 area(2)
# 期望输出：12.56

# 在这里写你的代码（可以用多个 cell：先建目录和文件，再写测试代码）

# %% [markdown]
# ### 4、`__all__` 练习

# %%
# 用 %%writefile 创建一个 tools.py：
# - 定义函数 useful()，print("这是公开函数")
# - 定义函数 _internal()，print("这是内部函数")
# - 设置 __all__ = ["useful"]
# 写完后用 from tools import * 导入，调用 useful()；
# 再尝试调用 _internal()，观察会发生什么报错，用注释写出报错类型和原因

# 在这里写你的代码

# %% [markdown]
# ### 5、pip / venv 命令默写

# %%
# 不用在 notebook 里运行，直接用注释写出对应的命令：
# 1. 创建一个名为 .venv 的虚拟环境
# 2. 激活这个虚拟环境（写 macOS/Linux 的命令即可）
# 3. 安装一个叫 requests 的第三方包
# 4. 把当前环境所有依赖导出到 requirements.txt
# 5. 根据 requirements.txt 安装所有依赖

# 在这里写出对应命令（每条前面加注释说明是第几步）
