# %% [markdown]
# # 数据类型 & 容器 · 练习

# %% [markdown]
# ### 1、列表索引与切片

# %%
# 有一个列表 nums = [10, 20, 30, 40, 50]
# 1. 用正数索引打印第一个元素
# 2. 用负数索引打印最后一个元素
# 3. 用切片打印前三个元素 [10, 20, 30]
# 4. 用切片打印后两个元素 [40, 50]
# 5. 用切片反转列表
# 期望输出：
# 10
# 50
# [10, 20, 30]
# [40, 50]
# [50, 40, 30, 20, 10]

# 在这里写你的代码

# %% [markdown]
# ### 2、列表增删改方法

# %%
# 有一个列表 fruits = ["apple", "banana"]
# 1. 用 append() 在末尾添加 "orange"
# 2. 用 insert() 在开头插入 "grape"
# 3. 用 extend() 拼接 ["pear", "peach"]
# 4. 用 remove() 删除 "banana"（按值删除）
# 5. 用 pop() 弹出最后一个元素，并打印弹出的值
# 6. 用 pop(0) 弹出第一个元素，并打印弹出的值
# 期望输出：
# 弹出的最后一个元素: peach
# 弹出的第一个元素: grape
# 最终列表: ['apple', 'orange', 'pear']

# 在这里写你的代码

# %% [markdown]
# ### 3、列表排序：sort() vs sorted()

# %%
# 有一个列表 nums = [5, 2, 8, 1, 9, 3]
# 1. 用 nums.sort() 原地升序排序，打印排序后的 nums
# 2. 用 nums.sort(reverse=True) 原地降序排序，打印排序后的 nums
# 3. 重新定义 nums = [5, 2, 8, 1, 9, 3]，用 sorted(nums) 生成新列表，打印新列表和原 nums（验证原列表不变）
# 期望输出：
# 升序后: [1, 2, 3, 5, 8, 9]
# 降序后: [9, 8, 5, 3, 2, 1]
# sorted 新列表: [1, 2, 3, 5, 8, 9]
# 原列表未变: [5, 2, 8, 1, 9, 3]

# 在这里写你的代码

# %% [markdown]
# ### 4、元组：解包与单元素陷阱

# %%
# 1. 定义一个坐标元组 point = (3, 4)，用解包赋值给 x, y 并打印
# 2. 验证 (1) 和 (1,) 的类型区别，打印它们的 type
# 3. 写一个函数 min_max(items)，返回最小值和最大值（用 tuple 返回）
#    调用 min_max([3, 1, 4, 1, 5])，用解包接收并打印
# 期望输出：
# x=3, y=4
# type((1)): <class 'int'>
# type((1,)): <class 'tuple'>
# 最小值: 1, 最大值: 5

# 在这里写你的代码

# %% [markdown]
# ### 5、字典基础操作：增、改、查、删

# %%
# 有一个字典 user = {"name": "Tom", "age": 18}
# 1. 新增键值对：添加 email = "tom@example.com"
# 2. 修改：把 age 改为 19
# 3. 用 [] 获取 name 的值
# 4. 用 get() 获取 phone，如果不存在返回 "未填写"
# 5. 用 del 删除 email 键值对
# 6. 打印最终的 user
# 期望输出：
# Tom
# 未填写
# {'name': 'Tom', 'age': 19}

# 在这里写你的代码

# %% [markdown]
# ### 6、字典遍历与 setdefault 分组累加

# %%
# 1. 遍历字典 user = {"name": "Tom", "age": 19, "city": "Beijing"}，打印每个 key 和 value
# 2. 分别打印 user.keys() 和 user.values()（转成 list）
# 3. 用 setdefault 或 get 统计单词列表的词频：
#    words = ["a", "b", "a", "c", "b", "a"]
#    期望输出：{'a': 3, 'b': 2, 'c': 1}

# 在这里写你的代码

# %% [markdown]
# ### 7、集合：去重与集合运算

# %%
# 1. 有一个列表 nums = [1, 2, 2, 3, 3, 3, 4]，用 set() 去重并打印
# 2. 定义两个集合 a = {1, 2, 3}, b = {2, 3, 4}
#    分别打印：并集 (|)、交集 (&)、差集 (-)、对称差 (^)
# 3. 用 add() 给 a 添加元素 5，用 discard() 删除元素 1，打印 a
# 期望输出：
# 去重后: {1, 2, 3, 4}
# 并集: {1, 2, 3, 4}
# 交集: {2, 3}
# 差集 a-b: {1}
# 对称差: {1, 4}
# 操作后 a: {2, 3, 5}

# 在这里写你的代码

# %% [markdown]
# ### 8、切片与序列通用操作

# %%
# 有一个字符串 s = "hello world"
# 1. 用切片取前 5 个字符 "hello"
# 2. 用切片隔一个取一个（步长为 2）
# 3. 用切片反转字符串
# 4. 用 len() 获取字符串长度
# 5. 用 in 判断 "world" 是否在 s 中
# 6. 用 + 拼接两个列表 [1, 2] + [3, 4]
# 7. 用 * 重复列表 [0] * 3
# 期望输出：
# hello
# hlowrd
# dlrow olleh
# 长度: 11
# 包含 world: True
# 拼接: [1, 2, 3, 4]
# 重复: [0, 0, 0]

# 在这里写你的代码

# %% [markdown]
# ### 9、推导式：列表、字典、集合

# %%
# 1. 用列表推导式生成 [0, 1, 4, 9, 16]（0~4 的平方）
# 2. 用列表推导式 + 条件过滤，生成 0~9 中的偶数列表 [0, 2, 4, 6, 8]
# 3. 用字典推导式生成 {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}（数字:平方）
# 4. 用集合推导式求 ["a", "bb", "ccc", "dd"] 中各字符串长度的集合
#    期望输出：
#    [0, 1, 4, 9, 16]
#    [0, 2, 4, 6, 8]
#    {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}
#    {1, 2, 3}

# 在这里写你的代码

# %% [markdown]
# ### 10、可变 vs 不可变 & 引用陷阱

# %%
# 1. 定义 a = [1, 2, 3]，然后 b = a（赋值，不是拷贝）
# 2. 对 b 执行 b.append(4)，打印 a，观察 a 是否也变了
# 3. 解释：为什么 a 也变了？用注释写下你的理解
# 期望输出：
# a 变成了: [1, 2, 3, 4]

# 在这里写你的代码

# %% [markdown]
# ### 11、浅拷贝 vs 深拷贝

# %%
import copy

# 有嵌套列表 nested = [[1, 2], [3, 4]]
# 1. 用 .copy() 浅拷贝一份叫 shallow，修改 shallow[0].append(99)，打印 nested 观察是否被改
# 2. 用 copy.deepcopy() 深拷贝一份叫 deep，修改 deep[0].append(100)，打印 nested 观察是否被改
# 3. 用注释解释浅拷贝和深拷贝的区别
# 期望输出：
# 浅拷贝后 nested: [[1, 2, 99], [3, 4]]
# 深拷贝后 nested: [[1, 2, 99], [3, 4]]（不受 deep 修改影响）
# deep: [[1, 2, 99, 100], [3, 4]]

# 在这里写你的代码

# %% [markdown]
# ### 12、函数默认参数陷阱

# %%
# 1. 写一个有问题的函数 add_item(item, items=[])，往 items 里追加 item 并返回
#    连续调用两次：add_item("a") 和 add_item("b")，观察第二次调用返回了什么
# 2. 写一个正确的函数 add_item_fixed(item, items=None)，用 None 作为默认值，函数内部判断创建新列表
#    连续调用两次：add_item_fixed("a") 和 add_item_fixed("b")，验证每次都是独立的新列表
# 期望输出：
# 有问题的函数:
# ['a']
# ['a', 'b']  <-- 不是预期的 ['b']！
# 正确的函数:
# ['a']
# ['b']

# 在这里写你的代码
