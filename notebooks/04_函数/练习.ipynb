# %% [markdown]
# # 函数 · 练习

# %% [markdown]
# ### 1、函数定义与返回值

# %%
# 1. 写一个函数 add(a, b)，返回 a + b
# 2. 写一个函数 no_return()，只打印 "没有 return"，不写 return
# 3. 写一个函数 min_max(nums)，返回最小值和最大值（tuple）
# 期望输出：
# 3
# None
# 1 5

# 在这里写你的代码

# %% [markdown]
# ### 2、位置参数 & 默认参数

# %%
# 1. 写函数 greet(name, greeting)，按位置打印 "{greeting}, {name}"
# 2. 写函数 greet2(name, greeting="Hello")，调用时省略 greeting
# 3. 写正确的 add_item(item, items=None)，避免可变默认参数陷阱
# 期望输出：
# Hello, Tom
# Hello, Tom
# Hi, Tom
# ["a"]
# ["b"]

# 在这里写你的代码

# %% [markdown]
# ### 3、关键字参数

# %%
# 1. 写函数 make_user(name, age, city)，用关键字参数调用（顺序打乱）
# 2. 写函数 connect(host, *, port=8080, timeout=30)，验证 port 必须用关键字传
# 期望输出：
# Tom, 18岁, 来自Beijing
# localhost 9090 30

# 在这里写你的代码

# %% [markdown]
# ### 4、*args 和 **kwargs

# %%
# 1. 写函数 my_sum(*args)，返回所有传入数字的和
# 2. 写函数 build_info(**kwargs)，拼接 "key=value" 字符串，用逗号分隔
# 3. 用 * 拆包列表 [1,2,3] 传给 my_sum
# 4. 用 ** 拆包字典 {"name":"Tom","age":18} 传给 build_info
# 期望输出：
# 15
# name=Tom, age=18, city=Beijing
# 6
# name=Tom, age=18

# 在这里写你的代码

# %% [markdown]
# ### 5、变量作用域

# %%
# 1. 写全局变量 counter = 0，写函数 click() 用 global 让 counter 加 1
# 2. 写嵌套函数 outer()/inner()，用 nonlocal 让 inner 修改 outer 的 x
# 期望输出：
# 3
# 1 2 3

# 在这里写你的代码

# %% [markdown]
# ### 6、lambda 表达式

# %%
# 1. 用 lambda 写 square = lambda x: x*x，打印 square(5)
# 2. 用 lambda 作为 sorted 的 key，按长度排序 words=["banana","kiwi","apple","fig"]
# 3. 用 lambda + filter 过滤 0~9 中的偶数
# 期望输出：
# 25
# ["fig", "kiwi", "apple", "banana"]
# [0, 2, 4, 6, 8]

# 在这里写你的代码

# %% [markdown]
# ### 7、函数是一等对象

# %%
# 1. 写函数 apply_twice(func, x)，对 x 应用 func 两次
#    测试：apply_twice(lambda x: x*2, 3) 应该返回 12
# 2. 写函数 make_multiplier(n)，返回一个函数，把输入乘以 n
#    测试：double = make_multiplier(2)，double(5) 应该返回 10
# 期望输出：
# 12
# 10

# 在这里写你的代码

# %% [markdown]
# ### 8、装饰器基础

# %%
# 写一个装饰器 @log_call，让被装饰函数每次调用时打印：
# "[LOG] 调用 xxx，参数: (...)"
# 
# 测试：
# @log_call
# def add(a, b):
#     return a + b
# 
# add(3, 4)
# 期望输出：
# [LOG] 调用 add，参数: (3, 4)

# 在这里写你的代码

# %% [markdown]
# ### 9、带参数的装饰器

# %%
# 写一个带参数的装饰器 @repeat(n)，让被装饰函数执行 n 次
# 
# 测试：
# @repeat(3)
# def greet(name):
#     print(f"Hello, {name}!")
# 
# greet("Tom")
# 期望输出：
# Hello, Tom!
# Hello, Tom!
# Hello, Tom!

# 在这里写你的代码

# %% [markdown]
# ### 10、functools.wraps 修复元信息

# %%
# 下面这个装饰器会导致被装饰函数的 __name__ 和 __doc__ 丢失
# 请用 @functools.wraps 修复它
# 
# def bold(func):
#     def wrapper(*args, **kwargs):
#         """wrapper 的文档"""
#         return f"<b>{func(*args, **kwargs)}</b>"
#     return wrapper
# 
# @bold
# def salute(name):
#     """返回一句问候语"""
#     return f"你好，{name}"
# 
# 修复后验证：
# print(salute.__name__)  # 应该是 salute
# print(salute.__doc__)   # 应该是 返回一句问候语

# 在这里写你的代码

# %% [markdown]
# ### 11、类型注解（Type Hints）

# %%
# 1. 写函数 add(a: int, b: int) -> int，标注参数和返回值类型
# 2. 写函数 greet(name: str, times: int = 3) -> str
# 3. 写函数 find_item(items: list, target: str)，找不到返回 None
# 期望输出：
# 3
# Hello, Tom!Hello, Tom!
# 1
# None

# 在这里写你的代码

# %% [markdown]
# ### 12、文档字符串（Docstring）

# %%
# 写一个函数 calculate_area(radius)，包含完整的文档字符串（描述功能、参数、返回值、异常）
# 函数内部：如果 radius <= 0，抛出 ValueError("半径必须大于 0")
# 否则返回 math.pi * radius ** 2
# 打印 calculate_area.__doc__ 查看文档字符串

# 在这里写你的代码

# %% [markdown]
# ### 13、递归函数

# %%
# 1. 写递归函数 factorial(n)，计算 n 的阶乘
# 2. 写递归函数 fibonacci(n)，返回第 n 个斐波那契数
# 期望输出：
# 120
# [0, 1, 1, 2, 3, 5, 8, 13]

# 在这里写你的代码

# %% [markdown]
# ### 14、生成器函数（yield）

# %%
# 1. 写生成器函数 count_up_to(n)，用 yield 生成 1 到 n 的数字
#    用 for 遍历 count_up_to(3)
# 2. 写生成器函数 fibonacci_gen()，无限生成斐波那契数
#    取前 8 个斐波那契数
# 期望输出：
# 1 2 3
# [0, 1, 1, 2, 3, 5, 8, 13]

# 在这里写你的代码

# %% [markdown]
# ### 15、强制位置参数（/ 语法）

# %%
# 1. 写函数 divide(a, b, /)，a 和 b 只能用位置传
#    测试：divide(10, 2) 返回 5.0
# 2. 写函数 func(a, /, b, c, *, d)，混合使用 / 和 *
#    测试：func(1, 2, c=3, d=4)
# 期望输出：
# 5.0
# 1 2 3 4

# 在这里写你的代码
